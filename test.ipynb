# %%
import pandas as pd

data = pd.read_csv("hackathon_practice_raw.csv")

df = pd.DataFrame(data)
df
# Out:
#      customer_id order_id       customer_name                        email  \
# 0         C10008  O200428         Nour Labser      nour.labser47@yahoo.com
# 1         C10315  O200954       Samir Bennani  samir.bennani65@outlook.com
# 2         C10331  O201051    Rania Ait Lahcen      rania.ait79@outlook.com
# 3         C10180  O200056    Karim El Fassi           karim.el86@gmail.com
# 4         C10080  O201154      Meryem Idrissi    meryem.idrissi5@yahoo.com
# ...          ...      ...                 ...                          ...
# 1300      C10272  O201239        Amina Labser      amina.labser9@gmail.com
# 1301      C10034  O200080        Amina Labser     amina.labser77@gmail.com
# 1302      C10207  O201099           Sara Tazi        sara.tazi35@yahoo.com
# 1303      C10200  O200326     Zakaria Idrissi  zakaria.idrissi71@yahoo.com
# 1304      C10019  O200531         Anas Alaoui      anas.alaoui32@yahoo.com
#
# ...

# %%
df.columns
# Out:
# Index(['product', 'price'], dtype='str')
